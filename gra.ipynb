# %%
from silnik import GRA

# %%
bot1 = "twoj_bot"
bot2 = "random_bot"

# %%
gra = GRA(bot1, bot2)
gra.start(show=True, notebook=True)
# Out:
# Runda: 4
#
# ╔═══╤═══╤═══╤═══╤═══╤═══╤═══╤═══╗
# ║   │ ● │   │ ● │   │ ● │   │ ● ║ 0
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║ ● │   │ ● │   │ ● │   │ ● │   ║ 1
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║   │ · │   │ ● │   │ ● │   │ ● ║ 2
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║ · │   │ ● │   │ · │   │ · │   ║ 3
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║   │ ● │   │ · │   │ · │   │ · ║ 4
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║ · │   │ ● │   │ ● │   │ ● │   ║ 5
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║   │ ● │   │ ● │   │ ● │   │ ● ║ 6
# ╟───┼───┼───┼───┼───┼───┼───┼───╢
# ║ ● │   │ ● │   │ ● │   │ ● │   ║ 7
# ╚═══╧═══╧═══╧═══╧═══╧═══╧═══╧═══╝
#   0   1   2   3   4   5   6   7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 gra = GRA(bot1, bot2)
# ----> 2 gra.start(show=True, notebook=True)
#
# ...
